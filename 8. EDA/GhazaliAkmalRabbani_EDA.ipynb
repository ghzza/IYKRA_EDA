# %% [markdown]
# # GhazaliAkmalRabbani - EDA

# %% [markdown]
# # Objective
#
# 1.	Is this data clean?
# 2.	How is the point distribution of the epl team? and which team is an anomaly?
# 3.	Which team has the best attack?
# 4.	Which team has the best defence?
# 5.	Which team is good in the financial aspect?
# 6.	Explore your creativity!

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('epl_1819.csv')
df.head()
# Out:
#               Team                        category  general_league_position  \
# 0  Manchester City                Champions League                        1
# 1        Liverpool                Champions League                        2
# 2          Chelsea  Champions League Qualification                        3
# 3        Tottenham  Champions League Qualification                        4
# 4          Arsenal                   Europa League                        5
#
#    finance _live_games_televised  finance _tv_revenue  general_matches_played  \
# 0                             26            150986355                      38
# 1                             29            152425146                      38
# 2                             25            146030216                      38
# 3                             26            145230801                      38
# 4                             25            142193180                      38
#
#    general_won  general_draw  general_lost  attack_scored  ...  defence_saves  \
# 0           32             2             4             95  ...             58
# 1           30             7             1             89  ...             76
# 2           21             9             8             63  ...             85
# 3           23             2            13             67  ...            121
# 4           21             7            10             73  ...            133
#
#    defence_blocks  defence_interceptions  defence_tackles  \
# 0              63                    362              518
# 1              78                    314              610
# 2              73                    351              618
# 3             112                    326              626
# 4             118                    412              609
#
#    defence_tackles_last_man  defence_clearances  defence_clearances_headed  \
# 0                         0                 543                        295
# 1                         2                 639                        317
# 2                         2                 593                        330
# 3                         3                 770                        411
# 4                         2                 762                        404
#
#    defence_penalty_conceeded attack_posession  attack_pass_accuracy
# 0                          4             64.0                  89.0
# 1                          1             58.8                  84.4
# 2                          2             59.9                  87.6
# 3                          5             56.7                  83.2
# 4                          7             56.1                  83.3
#
# [5 rows x 44 columns]

# %% [markdown]
# # Objective 1 (Data Preprocessing)
#
# **Is this data clean?**

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# Team                             0
# category                         0
# general_league_position          0
# finance _live_games_televised    0
# finance _tv_revenue              0
# general_matches_played           0
# general_won                      0
# general_draw                     0
# general_lost                     0
# attack_scored                    0
# defence_goals_conceeded          0
# general_goal_difference          0
# general_points                   0
# general_squad_size               0
# general_squad_average_age        0
# general_squad_foreigners         0
# finance _team_market             0
# finance _market_average          0
# attack_passes                    0
# attack_passes_through            0
# attack_passes_long               0
# attack_passes_back               0
# attack_crosses                   0
# attack_corners_taken             0
# attack_shots                     0
# attack_shots_on_target           0
# attack_goals_headed              0
# attack_goals_penalty             0
# attack_goals_box                 0
# attack_goals_outsidebox          0
# general_card_yellow              0
# general_card_red                 0
# attack_goals_counter             0
# attack_goals_freekick            0
# defence_saves                    0
# defence_blocks                   0
# defence_interceptions            0
# defence_tackles                  0
# defence_tackles_last_man         0
# defence_clearances               0
# defence_clearances_headed        0
# defence_penalty_conceeded        0
# attack_posession                 0
# attack_pass_accuracy             0
# dtype: int64

# %% [markdown]
# The dataset is already clean from null value

# %% [markdown]
# ## Check type of column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
#  12  general_points                 20 non-null     int64
#  13  general_squad_size             20 non-null     int64
#  14  general_squad_average_age      20 non-null     float64
#  15  general_squad_foreigners       20 non-null     int64
#  16  finance _team_market           20 non-null     int64
#  17  finance _market_average        20 non-null     int64
#  18  attack_passes                  20 non-null     object
#  19  attack_passes_through          20 non-null     int64
#  20  attack_passes_long             20 non-null     object
#  21  attack_passes_back             20 non-null     object
#  22  attack_crosses                 20 non-null     int64
#  23  attack_corners_taken           20 non-null     int64
#  24  attack_shots                   20 non-null     int64
#  25  attack_shots_on_target         20 non-null     int64
#  26  attack_goals_headed            20 non-null     int64
#  27  attack_goals_penalty           20 non-null     int64
#  28  attack_goals_box               20 non-null     int64
#  29  attack_goals_outsidebox        20 non-null     int64
#  30  general_card_yellow            20 non-null     int64
#  31  general_card_red               20 non-null     int64
#  32  attack_goals_counter           20 non-null     int64
#  33  attack_goals_freekick          20 non-null     int64
#  34  defence_saves                  20 non-null     int64
#  35  defence_blocks                 20 non-null     int64
#  36  defence_interceptions          20 non-null     int64
#  37  defence_tackles                20 non-null     int64
#  38  defence_tackles_last_man       20 non-null     int64
#  39  defence_clearances             20 non-null     object
#  40  defence_clearances_headed      20 non-null     int64
#  41  defence_penalty_conceeded      20 non-null     int64
#  42  attack_posession               20 non-null     float64
#  43  attack_pass_accuracy           20 non-null     float64
# dtypes: float64(3), int64(35), object(6)
# memory usage: 7.0+ KB

# %% [markdown]
# Based on result in above, I will convert type of attack_passes,attack_passes_long,attack_passes_back and defence_clearances column from object to float64 type

# %% [markdown]
# ## Before Convert the Column

# %%
df['attack_passes']
# Out:
# 0     26,581
# 1     23,638
# 2     25,070
# 3     21,295
# 4     20,805
# 5     19,202
# 6     16,618
# 7     16,494
# 8     17,219
# 9     16,358
# 10    15,462
# 11    15,243
# 12    13,490
# 13    15,943
# 14    13,011
# 15    14,297
# 16    14,109
# 17    10,226
# 18    17,699
# 19    15,902
# Name: attack_passes, dtype: object

# %% [markdown]
# ## Convert The Column

# %%
df['attack_passes'] = df['attack_passes'].replace({',' : ''}, regex=True).astype('int64')
df['attack_passes_long'] = df['attack_passes_long'].replace({',' : ''}, regex=True).astype('int64')
df['attack_passes_back'] = df['attack_passes_back'].replace({',' : ''}, regex=True).astype('int64')
df['defence_clearances'] = df['defence_clearances'].replace({',' : ''}, regex=True).astype('int64')

# %% [markdown]
# ## After Convert the Column

# %%
df['attack_passes']
# Out:
# 0     26581
# 1     23638
# 2     25070
# 3     21295
# 4     20805
# 5     19202
# 6     16618
# 7     16494
# 8     17219
# 9     16358
# 10    15462
# 11    15243
# 12    13490
# 13    15943
# 14    13011
# 15    14297
# 16    14109
# 17    10226
# 18    17699
# 19    15902
# Name: attack_passes, dtype: int64

# %%
df['attack_passes_long']
# Out:
# 0     1814
# 1     2250
# 2     1774
# 3     2267
# 4     2062
# 5     2242
# 6     2552
# 7     2310
# 8     2335
# 9     2315
# 10    2437
# 11    2259
# 12    2680
# 13    1932
# 14    2898
# 15    2394
# 16    2623
# 17    2513
# 18    2417
# 19    2603
# Name: attack_passes_long, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
#  12  general_points                 20 non-null     int64
#  13  general_squad_size             20 non-null     int64
#  14  general_squad_average_age      20 non-null     float64
#  15  general_squad_foreigners       20 non-null     int64
#  16  finance _team_market           20 non-null     int64
#  17  finance _market_average        20 non-null     int64
#  18  attack_passes                  20 non-null     int64
#  19  attack_passes_through          20 non-null     int64
#  20  attack_passes_long             20 non-null     int64
#  21  attack_passes_back             20 non-null     int64
#  22  attack_crosses                 20 non-null     int64
#  23  attack_corners_taken           20 non-null     int64
#  24  attack_shots                   20 non-null     int64
#  25  attack_shots_on_target         20 non-null     int64
#  26  attack_goals_headed            20 non-null     int64
#  27  attack_goals_penalty           20 non-null     int64
#  28  attack_goals_box               20 non-null     int64
#  29  attack_goals_outsidebox        20 non-null     int64
#  30  general_card_yellow            20 non-null     int64
#  31  general_card_red               20 non-null     int64
#  32  attack_goals_counter           20 non-null     int64
#  33  attack_goals_freekick          20 non-null     int64
#  34  defence_saves                  20 non-null     int64
#  35  defence_blocks                 20 non-null     int64
#  36  defence_interceptions          20 non-null     int64
#  37  defence_tackles                20 non-null     int64
#  38  defence_tackles_last_man       20 non-null     int64
#  39  defence_clearances             20 non-null     int64
#  40  defence_clearances_headed      20 non-null     int64
#  41  defence_penalty_conceeded      20 non-null     int64
#  42  attack_posession               20 non-null     float64
#  43  attack_pass_accuracy           20 non-null     float64
# dtypes: float64(3), int64(39), object(2)
# memory usage: 7.0+ KB

# %% [markdown]
# Until this step, the dataset is already clean and ready to be explored

# %% [markdown]
# # Objective 2
#
# **How is the point distribution of the epl team? and which team is an anomaly?**

# %% [markdown]
# ## Point Distribution of EPL Team
#
# To check point distribution of the EPL Team, I will do it by Boxplot

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df['general_points']).set_title('Point Distribution')
mean = df['general_points'].mean()
median = df['general_points'].median()
FirstQuartile = df['general_points'].quantile(0.25)
ThirdQuartile = df['general_points'].quantile(0.75)
Interquartile = scipy.stats.iqr(df['general_points'])
UpperFence = ThirdQuartile + (1.5*Interquartile)
LowerFence = FirstQuartile - (1.5*Interquartile)

print ('==================================')
print ('Statistical Data Summary')
print ('==================================')
print ('Mean : ', mean)
print ('Median : ', median)
print ('1st Quartile : ', FirstQuartile)
print ('3rd Quartile : ', ThirdQuartile)
print ('IQR : ', Interquartile)
print ('Upper Fence : ', UpperFence)
print ('Lower Fence : ', LowerFence)
print ('==================================')

UpperOutliers = []
LowerOutliers = []
StatusUpperOutliers = False
StatusLowerOutliers = False
for x in df['general_points']:
  if (x > UpperFence):
    UpperOutliers.append(x)
    StatusUpperOutliers = True
  elif (x < LowerFence):
    LowerOutliers.append(x)
    StatusLowerOutliers = True
print ()
print ('==================================')
print ('Outliers Data Detection')
print ('==================================')
print ('Upper Outliers Data : ', sorted(UpperOutliers, reverse=False))
print ('Upper Outliers Status : ', StatusUpperOutliers)
print ('Lower Outliers Data : ', sorted(LowerOutliers, reverse=False))
print ('Lower Outliers Status : ', StatusLowerOutliers)

plt.figure(figsize = (10, 6))
sns.boxplot(df['general_points'], showfliers = False).set_title('Point Distribution No Outliers')
# Out:
# ==================================
# Statistical Data Summary
# ==================================
# Mean :  53.45
# Median :  51.0
# 1st Quartile :  39.75
# 3rd Quartile :  67.0
# IQR :  27.25
# Upper Fence :  107.875
# Lower Fence :  -1.125
# ==================================
#
# ==================================
# Outliers Data Detection
# ==================================
# Upper Outliers Data :  []
# Upper Outliers Status :  False
# Lower Outliers Data :  []
# Lower Outliers Status :  False
# C:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Point Distribution No Outliers')

# %% [markdown]
# ## Anomaly Team

# %% [markdown]
# ### What is Anomaly ?
#
# Based on anadot.com, Anomaly detection (aka outlier analysis) is a step in data mining that identifies data points, events, and/or observations that deviate from a dataset’s normal behavior. Anomalous data can indicate critical incidents, such as a technical glitch, or potential opportunities, for instance a change in consumer behavior. (src : https://www.anodot.com/blog/what-is-anomaly-detection/ )
#
# How do you detect the outliers or What are the methods used for detecting anomalies?
#
# 1. Using data visualization(like making use of boxplots, violin plots…etc)
#
# 2. Using Statistical methods like Quantile methods(IQR, Q1, Q3), Finding Minimum, Maximum, and median of the data, Z-score, etc.
#
# 3. ML algorithms like IsolationForest, LocalOutlierFactor, OneClassSVM, Elliptic Envelope …etc.
#
# (src : https://www.analyticsvidhya.com/blog/2021/04/dealing-with-anomalies-in-the-data/ )

# %% [markdown]
# ### Which team is an anomaly ?
#
# Based on the result in Boxplot in the above, there is no team which considered as anomaly team based on point distribution. Because there is no outliers in point distribution which visualized by boxplot in above.

# %% [markdown]
# # Objective 3
#
# **Which team has the best attack?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
#  12  general_points                 20 non-null     int64
#  13  general_squad_size             20 non-null     int64
#  14  general_squad_average_age      20 non-null     float64
#  15  general_squad_foreigners       20 non-null     int64
#  16  finance _team_market           20 non-null     int64
#  17  finance _market_average        20 non-null     int64
#  18  attack_passes                  20 non-null     int64
#  19  attack_passes_through          20 non-null     int64
#  20  attack_passes_long             20 non-null     int64
#  21  attack_passes_back             20 non-null     int64
#  22  attack_crosses                 20 non-null     int64
#  23  attack_corners_taken           20 non-null     int64
#  24  attack_shots                   20 non-null     int64
#  25  attack_shots_on_target         20 non-null     int64
#  26  attack_goals_headed            20 non-null     int64
#  27  attack_goals_penalty           20 non-null     int64
#  28  attack_goals_box               20 non-null     int64
#  29  attack_goals_outsidebox        20 non-null     int64
#  30  general_card_yellow            20 non-null     int64
#  31  general_card_red               20 non-null     int64
#  32  attack_goals_counter           20 non-null     int64
#  33  attack_goals_freekick          20 non-null     int64
#  34  defence_saves                  20 non-null     int64
#  35  defence_blocks                 20 non-null     int64
#  36  defence_interceptions          20 non-null     int64
#  37  defence_tackles                20 non-null     int64
#  38  defence_tackles_last_man       20 non-null     int64
#  39  defence_clearances             20 non-null     int64
#  40  defence_clearances_headed      20 non-null     int64
#  41  defence_penalty_conceeded      20 non-null     int64
#  42  attack_posession               20 non-null     float64
#  43  attack_pass_accuracy           20 non-null     float64
# dtypes: float64(3), int64(39), object(2)
# memory usage: 7.0+ KB

# %% [markdown]
# ## Collect data which contains a meaning in attack

# %%
dfAttackData = df[['attack_scored', 'attack_passes',
                   'attack_passes_through','attack_passes_long',
                   'attack_passes_back','attack_crosses',
                   'attack_crosses','attack_corners_taken', 
                   'attack_shots','attack_shots_on_target', 
                   'attack_goals_headed','attack_goals_penalty', 
                   'attack_goals_box','attack_goals_outsidebox', 
                   'attack_goals_counter','attack_goals_freekick', 
                   'attack_posession', 'attack_pass_accuracy']]
dfAttackData
# Out:
#     attack_scored  attack_passes  attack_passes_through  attack_passes_long  \
# 0              95          26581                    112                1814
# 1              89          23638                     98                2250
# 2              63          25070                    146                1774
# 3              67          21295                     87                2267
# 4              73          20805                     65                2062
# 5              65          19202                     63                2242
# 6              47          16618                     51                2552
# 7              54          16494                     44                2310
# 8              51          17219                     88                2335
# 9              52          16358                     75                2315
# 10             52          15462                     32                2437
# 11             51          15243                     26                2259
# 12             42          13490                     50                2680
# 13             56          15943                     57                1932
# 14             45          13011                     35                2898
# 15             45          14297                     35                2394
# 16             35          14109                     15                2623
# 17             34          10226                     39                2513
# 18             34          17699                     33                2417
# 19             22          15902                     23                2603
#
#     attack_passes_back  attack_crosses  attack_crosses  attack_corners_taken  \
# 0                 4240             783             783                   298
# 1                 3416             721             721                   249
# 2                 3874             692             692                   215
# 3                 3191             643             643                   194
# 4                 3102             605             605                   209
# 5                 2634             638             638                   200
# 6                 2515             622             622                   195
# 7                 2362             814             814                   215
# 8                 2593             779             779                   210
# 9                 2273             630             630                   188
# 10                2314             570             570                   177
# 11                2233             577             577                   205
# 12                1999             711             711                   181
# 13                2249             613             613                   191
# 14                2046             693             693                   140
# 15                2040             664             664                   193
# 16                2072             636             636                   156
# 17                1418             562             562                   168
# 18                2750             611             611                   161
# 19                2492             769             769                   162
#
#     attack_shots  attack_shots_on_target  attack_goals_headed  \
# 0            683                     260                   12
# 1            575                     226                   19
# 2            607                     198                    8
# 3            537                     189                   14
# 4            467                     170                    5
# 5            526                     225                    4
# 6            477                     152                   10
# 7            498                     169                   13
# 8            515                     184                    9
# 9            441                     157                   10
# 10           437                     152                    8
# 11           493                     148                    5
# 12           446                     142                   12
# 13           446                     163                   11
# 14           360                     116                   13
# 15           483                     162                    4
# 16           371                     108                   10
# 17           417                     126                    4
# 18           454                     146                    7
# 19           400                     118                    8
#
#     attack_goals_penalty  attack_goals_box  attack_goals_outsidebox  \
# 0                      3                80                       15
# 1                      7                84                        5
# 2                      5                54                        9
# 3                      4                53                       14
# 4                      4                62                       11
# 5                      9                55                       10
# 6                      4                44                        3
# 7                      2                45                       10
# 8                      5                43                        8
# 9                      5                47                        5
# 10                     1                44                        8
# 11                    10                43                        8
# 12                     1                40                        2
# 13                     7                50                        6
# 14                     2                43                        2
# 15                     4                31                       14
# 16                     5                34                        1
# 17                     3                29                        5
# 18                     2                30                        4
# 19                     1                17                        5
#
#     attack_goals_counter  attack_goals_freekick  attack_posession  \
# 0                      5                      2              64.0
# 1                      6                      1              58.8
# 2                      1                      1              59.9
# 3                      5                      2              56.7
# 4                      3                      3              56.1
# 5                      4                      2              53.3
# 6                      5                      2              47.4
# 7                      3                      0              51.0
# 8                      8                      3              50.8
# 9                      3                      0              49.0
# 10                     3                      0              47.4
# 11                     2                      2              46.6
# 12                     1                      1              42.9
# 13                     9                      0              47.7
# 14                     1                      0              43.4
# 15                     1                      3              45.4
# 16                     4                      0              44.1
# 17                     0                      0              39.1
# 18                     2                      0              49.2
# 19                     1                      1              47.1
#
#     attack_pass_accuracy
# 0                   89.0
# 1                   84.4
# 2                   87.6
# 3                   83.2
# 4                   83.3
# 5                   82.3
# 6                   78.2
# 7                   77.3
# 8                   79.2
# 9                   78.7
# 10                  76.1
# 11                  76.8
# 12                  72.9
# 13                  78.1
# 14                  70.3
# 15                  74.0
# 16                  74.8
# 17                  63.9
# 18                  80.3
# 19                  75.8

# %% [markdown]
# ## Find the team who has Best Attack by Find the Highest Mean of Attack Data

# %% [markdown]
# ### Calculate the mean of all data of each team

# %%
dfAttackData['MeanAttackData'] = dfAttackData.mean(axis=1)
dfAttackData
# Out:
# <ipython-input-13-614536655c8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfAttackData['MeanAttackData'] = dfAttackData.mean(axis=1)
#     attack_scored  attack_passes  attack_passes_through  attack_passes_long  \
# 0              95          26581                    112                1814
# 1              89          23638                     98                2250
# 2              63          25070                    146                1774
# 3              67          21295                     87                2267
# 4              73          20805                     65                2062
# 5              65          19202                     63                2242
# 6              47          16618                     51                2552
# 7              54          16494                     44                2310
# 8              51          17219                     88                2335
# 9              52          16358                     75                2315
# 10             52          15462                     32                2437
# 11             51          15243                     26                2259
# 12             42          13490                     50                2680
# 13             56          15943                     57                1932
# 14             45          13011                     35                2898
# 15             45          14297                     35                2394
# 16             35          14109                     15                2623
# 17             34          10226                     39                2513
# 18             34          17699                     33                2417
# 19             22          15902                     23                2603
#
#     attack_passes_back  attack_crosses  attack_crosses  attack_corners_taken  \
# 0                 4240             783             783                   298
# 1                 3416             721             721                   249
# 2                 3874             692             692                   215
# 3                 3191             643             643                   194
# 4                 3102             605             605                   209
# 5                 2634             638             638                   200
# 6                 2515             622             622                   195
# 7                 2362             814             814                   215
# 8                 2593             779             779                   210
# 9                 2273             630             630                   188
# 10                2314             570             570                   177
# 11                2233             577             577                   205
# 12                1999             711             711                   181
# 13                2249             613             613                   191
# 14                2046             693             693                   140
# 15                2040             664             664                   193
# 16                2072             636             636                   156
# 17                1418             562             562                   168
# 18                2750             611             611                   161
# 19                2492             769             769                   162
#
#     attack_shots  attack_shots_on_target  attack_goals_headed  \
# 0            683                     260                   12
# 1            575                     226                   19
# 2            607                     198                    8
# 3            537                     189                   14
# 4            467                     170                    5
# 5            526                     225                    4
# 6            477                     152                   10
# 7            498                     169                   13
# 8            515                     184                    9
# 9            441                     157                   10
# 10           437                     152                    8
# 11           493                     148                    5
# 12           446                     142                   12
# 13           446                     163                   11
# 14           360                     116                   13
# 15           483                     162                    4
# 16           371                     108                   10
# 17           417                     126                    4
# 18           454                     146                    7
# 19           400                     118                    8
#
#     attack_goals_penalty  attack_goals_box  attack_goals_outsidebox  \
# 0                      3                80                       15
# 1                      7                84                        5
# 2                      5                54                        9
# 3                      4                53                       14
# 4                      4                62                       11
# 5                      9                55                       10
# 6                      4                44                        3
# 7                      2                45                       10
# 8                      5                43                        8
# 9                      5                47                        5
# 10                     1                44                        8
# 11                    10                43                        8
# 12                     1                40                        2
# 13                     7                50                        6
# 14                     2                43                        2
# 15                     4                31                       14
# 16                     5                34                        1
# 17                     3                29                        5
# 18                     2                30                        4
# 19                     1                17                        5
#
#     attack_goals_counter  attack_goals_freekick  attack_posession  \
# 0                      5                      2              64.0
# 1                      6                      1              58.8
# 2                      1                      1              59.9
# 3                      5                      2              56.7
# 4                      3                      3              56.1
# 5                      4                      2              53.3
# 6                      5                      2              47.4
# 7                      3                      0              51.0
# 8                      8                      3              50.8
# 9                      3                      0              49.0
# 10                     3                      0              47.4
# 11                     2                      2              46.6
# 12                     1                      1              42.9
# 13                     9                      0              47.7
# 14                     1                      0              43.4
# 15                     1                      3              45.4
# 16                     4                      0              44.1
# 17                     0                      0              39.1
# 18                     2                      0              49.2
# 19                     1                      1              47.1
#
#     attack_pass_accuracy  MeanAttackData
# 0                   89.0     1995.500000
# 1                   84.4     1791.566667
# 2                   87.6     1864.250000
# 3                   83.2     1630.272222
# 4                   83.3     1577.244444
# 5                   82.3     1480.700000
# 6                   78.2     1335.811111
# 7                   77.3     1331.961111
# 8                   79.2     1386.611111
# 9                   78.7     1295.372222
# 10                  76.1     1243.916667
# 11                  76.8     1222.522222
# 12                  72.9     1145.822222
# 13                  78.1     1248.433333
# 14                  70.3     1122.872222
# 15                  74.0     1175.188889
# 16                  74.8     1162.994444
# 17                  63.9      900.500000
# 18                  80.3     1393.916667
# 19                  75.8     1300.883333

# %% [markdown]
# ### Add Team Name Column to dfAttackData from df

# %%
dfAttackData = dfAttackData.join(df['Team'])
dfAttackData
# Out:
#     attack_scored  attack_passes  attack_passes_through  attack_passes_long  \
# 0              95          26581                    112                1814
# 1              89          23638                     98                2250
# 2              63          25070                    146                1774
# 3              67          21295                     87                2267
# 4              73          20805                     65                2062
# 5              65          19202                     63                2242
# 6              47          16618                     51                2552
# 7              54          16494                     44                2310
# 8              51          17219                     88                2335
# 9              52          16358                     75                2315
# 10             52          15462                     32                2437
# 11             51          15243                     26                2259
# 12             42          13490                     50                2680
# 13             56          15943                     57                1932
# 14             45          13011                     35                2898
# 15             45          14297                     35                2394
# 16             35          14109                     15                2623
# 17             34          10226                     39                2513
# 18             34          17699                     33                2417
# 19             22          15902                     23                2603
#
#     attack_passes_back  attack_crosses  attack_crosses  attack_corners_taken  \
# 0                 4240             783             783                   298
# 1                 3416             721             721                   249
# 2                 3874             692             692                   215
# 3                 3191             643             643                   194
# 4                 3102             605             605                   209
# 5                 2634             638             638                   200
# 6                 2515             622             622                   195
# 7                 2362             814             814                   215
# 8                 2593             779             779                   210
# 9                 2273             630             630                   188
# 10                2314             570             570                   177
# 11                2233             577             577                   205
# 12                1999             711             711                   181
# 13                2249             613             613                   191
# 14                2046             693             693                   140
# 15                2040             664             664                   193
# 16                2072             636             636                   156
# 17                1418             562             562                   168
# 18                2750             611             611                   161
# 19                2492             769             769                   162
#
#     attack_shots  attack_shots_on_target  attack_goals_headed  \
# 0            683                     260                   12
# 1            575                     226                   19
# 2            607                     198                    8
# 3            537                     189                   14
# 4            467                     170                    5
# 5            526                     225                    4
# 6            477                     152                   10
# 7            498                     169                   13
# 8            515                     184                    9
# 9            441                     157                   10
# 10           437                     152                    8
# 11           493                     148                    5
# 12           446                     142                   12
# 13           446                     163                   11
# 14           360                     116                   13
# 15           483                     162                    4
# 16           371                     108                   10
# 17           417                     126                    4
# 18           454                     146                    7
# 19           400                     118                    8
#
#     attack_goals_penalty  attack_goals_box  attack_goals_outsidebox  \
# 0                      3                80                       15
# 1                      7                84                        5
# 2                      5                54                        9
# 3                      4                53                       14
# 4                      4                62                       11
# 5                      9                55                       10
# 6                      4                44                        3
# 7                      2                45                       10
# 8                      5                43                        8
# 9                      5                47                        5
# 10                     1                44                        8
# 11                    10                43                        8
# 12                     1                40                        2
# 13                     7                50                        6
# 14                     2                43                        2
# 15                     4                31                       14
# 16                     5                34                        1
# 17                     3                29                        5
# 18                     2                30                        4
# 19                     1                17                        5
#
#     attack_goals_counter  attack_goals_freekick  attack_posession  \
# 0                      5                      2              64.0
# 1                      6                      1              58.8
# 2                      1                      1              59.9
# 3                      5                      2              56.7
# 4                      3                      3              56.1
# 5                      4                      2              53.3
# 6                      5                      2              47.4
# 7                      3                      0              51.0
# 8                      8                      3              50.8
# 9                      3                      0              49.0
# 10                     3                      0              47.4
# 11                     2                      2              46.6
# 12                     1                      1              42.9
# 13                     9                      0              47.7
# 14                     1                      0              43.4
# 15                     1                      3              45.4
# 16                     4                      0              44.1
# 17                     0                      0              39.1
# 18                     2                      0              49.2
# 19                     1                      1              47.1
#
#     attack_pass_accuracy  MeanAttackData               Team
# 0                   89.0     1995.500000    Manchester City
# 1                   84.4     1791.566667          Liverpool
# 2                   87.6     1864.250000            Chelsea
# 3                   83.2     1630.272222          Tottenham
# 4                   83.3     1577.244444            Arsenal
# 5                   82.3     1480.700000  Manchester United
# 6                   78.2     1335.811111      Wolverhampton
# 7                   77.3     1331.961111            Everton
# 8                   79.2     1386.611111          Leicester
# 9                   78.7     1295.372222           West Ham
# 10                  76.1     1243.916667            Watford
# 11                  76.8     1222.522222     Crystal Palace
# 12                  72.9     1145.822222          Newcastle
# 13                  78.1     1248.433333        Bournemouth
# 14                  70.3     1122.872222            Burnley
# 15                  74.0     1175.188889        Southampton
# 16                  74.8     1162.994444           Brighton
# 17                  63.9      900.500000            Cardiff
# 18                  80.3     1393.916667             Fulham
# 19                  75.8     1300.883333       Huddersfield

# %% [markdown]
# ### Find the Highest of Mean Attack Data

# %%
dfAttackData['MeanAttackData'].max()
# Out:
# 1995.5

# %%
dfBestAttackTeam = dfAttackData[dfAttackData['MeanAttackData'] == 1995.5]
dfBestAttackTeam
# Out:
#    attack_scored  attack_passes  attack_passes_through  attack_passes_long  \
# 0             95          26581                    112                1814
#
#    attack_passes_back  attack_crosses  attack_crosses  attack_corners_taken  \
# 0                4240             783             783                   298
#
#    attack_shots  attack_shots_on_target  attack_goals_headed  \
# 0           683                     260                   12
#
#    attack_goals_penalty  attack_goals_box  attack_goals_outsidebox  \
# 0                     3                80                       15
#
#    attack_goals_counter  attack_goals_freekick  attack_posession  \
# 0                     5                      2              64.0
#
#    attack_pass_accuracy  MeanAttackData             Team
# 0                  89.0          1995.5  Manchester City

# %% [markdown]
# # Objective 4
#
# **Which team has the best defence?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
#  12  general_points                 20 non-null     int64
#  13  general_squad_size             20 non-null     int64
#  14  general_squad_average_age      20 non-null     float64
#  15  general_squad_foreigners       20 non-null     int64
#  16  finance _team_market           20 non-null     int64
#  17  finance _market_average        20 non-null     int64
#  18  attack_passes                  20 non-null     int64
#  19  attack_passes_through          20 non-null     int64
#  20  attack_passes_long             20 non-null     int64
#  21  attack_passes_back             20 non-null     int64
#  22  attack_crosses                 20 non-null     int64
#  23  attack_corners_taken           20 non-null     int64
#  24  attack_shots                   20 non-null     int64
#  25  attack_shots_on_target         20 non-null     int64
#  26  attack_goals_headed            20 non-null     int64
#  27  attack_goals_penalty           20 non-null     int64
#  28  attack_goals_box               20 non-null     int64
#  29  attack_goals_outsidebox        20 non-null     int64
#  30  general_card_yellow            20 non-null     int64
#  31  general_card_red               20 non-null     int64
#  32  attack_goals_counter           20 non-null     int64
#  33  attack_goals_freekick          20 non-null     int64
#  34  defence_saves                  20 non-null     int64
#  35  defence_blocks                 20 non-null     int64
#  36  defence_interceptions          20 non-null     int64
#  37  defence_tackles                20 non-null     int64
#  38  defence_tackles_last_man       20 non-null     int64
#  39  defence_clearances             20 non-null     int64
#  40  defence_clearances_headed      20 non-null     int64
#  41  defence_penalty_conceeded      20 non-null     int64
#  42  attack_posession               20 non-null     float64
#  43  attack_pass_accuracy           20 non-null     float64
# dtypes: float64(3), int64(39), object(2)
# memory usage: 7.0+ KB

# %% [markdown]
# ## Collect data which contains a meaning in defense

# %%
dfDefenceData = df.iloc[:, 34:41]
dfDefenceData
# Out:
#     defence_saves  defence_blocks  defence_interceptions  defence_tackles  \
# 0              58              63                    362              518
# 1              76              78                    314              610
# 2              85              73                    351              618
# 3             121             112                    326              626
# 4             133             118                    412              609
# 5             122             128                    355              581
# 6             100             148                    501              720
# 7              94              85                    456              700
# 8              90              96                    436              676
# 9             148             141                    457              723
# 10            127             120                    426              655
# 11            113             141                    446              730
# 12             95             134                    506              714
# 13            110             152                    371              526
# 14            140             222                    365              583
# 15            114             153                    548              699
# 16            111             170                    463              681
# 17            141             147                    528              655
# 18            147             144                    433              591
# 19            114             130                    530              710
#
#     defence_tackles_last_man  defence_clearances  defence_clearances_headed
# 0                          0                 543                        295
# 1                          2                 639                        317
# 2                          2                 593                        330
# 3                          3                 770                        411
# 4                          2                 762                        404
# 5                          2                 785                        370
# 6                          2                 824                        464
# 7                          4                 825                        430
# 8                          4                 945                        500
# 9                          5                 855                        397
# 10                         8                 956                        447
# 11                         2                 940                        467
# 12                         4                1120                        564
# 13                         5                1019                        515
# 14                         5                1080                        539
# 15                         4                1068                        502
# 16                         4                 921                        499
# 17                         4                 978                        448
# 18                         0                 971                        443
# 19                         2                 658                        246

# %% [markdown]
# ## Find the team who has Best Defense by Find the Highest Mean of Defense Data

# %% [markdown]
# ### Calculate the mean of all data of each team

# %%
dfDefenceData['MeanDefenceData'] = dfDefenceData.mean(axis=1)
dfDefenceData
# Out:
#     defence_saves  defence_blocks  defence_interceptions  defence_tackles  \
# 0              58              63                    362              518
# 1              76              78                    314              610
# 2              85              73                    351              618
# 3             121             112                    326              626
# 4             133             118                    412              609
# 5             122             128                    355              581
# 6             100             148                    501              720
# 7              94              85                    456              700
# 8              90              96                    436              676
# 9             148             141                    457              723
# 10            127             120                    426              655
# 11            113             141                    446              730
# 12             95             134                    506              714
# 13            110             152                    371              526
# 14            140             222                    365              583
# 15            114             153                    548              699
# 16            111             170                    463              681
# 17            141             147                    528              655
# 18            147             144                    433              591
# 19            114             130                    530              710
#
#     defence_tackles_last_man  defence_clearances  defence_clearances_headed  \
# 0                          0                 543                        295
# 1                          2                 639                        317
# 2                          2                 593                        330
# 3                          3                 770                        411
# 4                          2                 762                        404
# 5                          2                 785                        370
# 6                          2                 824                        464
# 7                          4                 825                        430
# 8                          4                 945                        500
# 9                          5                 855                        397
# 10                         8                 956                        447
# 11                         2                 940                        467
# 12                         4                1120                        564
# 13                         5                1019                        515
# 14                         5                1080                        539
# 15                         4                1068                        502
# 16                         4                 921                        499
# 17                         4                 978                        448
# 18                         0                 971                        443
# 19                         2                 658                        246
#
#     MeanDefenceData
# 0        262.714286
# 1        290.857143
# 2        293.142857
# 3        338.428571
# 4        348.571429
# 5        334.714286
# 6        394.142857
# 7        370.571429
# 8        392.428571
# 9        389.428571
# 10       391.285714
# 11       405.571429
# 12       448.142857
# 13       385.428571
# 14       419.142857
# 15       441.142857
# 16       407.000000
# 17       414.428571
# 18       389.857143
# 19       341.428571

# %% [markdown]
# ### Add Team Name Column to dfAttackData from df

# %%
dfDefenceData = dfDefenceData.join(df['Team'])
dfDefenceData
# Out:
#     defence_saves  defence_blocks  defence_interceptions  defence_tackles  \
# 0              58              63                    362              518
# 1              76              78                    314              610
# 2              85              73                    351              618
# 3             121             112                    326              626
# 4             133             118                    412              609
# 5             122             128                    355              581
# 6             100             148                    501              720
# 7              94              85                    456              700
# 8              90              96                    436              676
# 9             148             141                    457              723
# 10            127             120                    426              655
# 11            113             141                    446              730
# 12             95             134                    506              714
# 13            110             152                    371              526
# 14            140             222                    365              583
# 15            114             153                    548              699
# 16            111             170                    463              681
# 17            141             147                    528              655
# 18            147             144                    433              591
# 19            114             130                    530              710
#
#     defence_tackles_last_man  defence_clearances  defence_clearances_headed  \
# 0                          0                 543                        295
# 1                          2                 639                        317
# 2                          2                 593                        330
# 3                          3                 770                        411
# 4                          2                 762                        404
# 5                          2                 785                        370
# 6                          2                 824                        464
# 7                          4                 825                        430
# 8                          4                 945                        500
# 9                          5                 855                        397
# 10                         8                 956                        447
# 11                         2                 940                        467
# 12                         4                1120                        564
# 13                         5                1019                        515
# 14                         5                1080                        539
# 15                         4                1068                        502
# 16                         4                 921                        499
# 17                         4                 978                        448
# 18                         0                 971                        443
# 19                         2                 658                        246
#
#     MeanDefenceData               Team
# 0        262.714286    Manchester City
# 1        290.857143          Liverpool
# 2        293.142857            Chelsea
# 3        338.428571          Tottenham
# 4        348.571429            Arsenal
# 5        334.714286  Manchester United
# 6        394.142857      Wolverhampton
# 7        370.571429            Everton
# 8        392.428571          Leicester
# 9        389.428571           West Ham
# 10       391.285714            Watford
# 11       405.571429     Crystal Palace
# 12       448.142857          Newcastle
# 13       385.428571        Bournemouth
# 14       419.142857            Burnley
# 15       441.142857        Southampton
# 16       407.000000           Brighton
# 17       414.428571            Cardiff
# 18       389.857143             Fulham
# 19       341.428571       Huddersfield

# %% [markdown]
# ### Find the Highest of Mean Defence Data

# %%
dfDefenceData['MeanDefenceData'].max()
# Out:
# 448.14285714285717

# %%
dfBestDefenceTeam = dfDefenceData[dfDefenceData['MeanDefenceData'] == 448.14285714285717]
dfBestDefenceTeam
# Out:
#     defence_saves  defence_blocks  defence_interceptions  defence_tackles  \
# 12             95             134                    506              714
#
#     defence_tackles_last_man  defence_clearances  defence_clearances_headed  \
# 12                         4                1120                        564
#
#     MeanDefenceData       Team
# 12       448.142857  Newcastle

# %% [markdown]
# # Objective 5
#
# **Which team is good in the financial aspect?**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
#  12  general_points                 20 non-null     int64
#  13  general_squad_size             20 non-null     int64
#  14  general_squad_average_age      20 non-null     float64
#  15  general_squad_foreigners       20 non-null     int64
#  16  finance _team_market           20 non-null     int64
#  17  finance _market_average        20 non-null     int64
#  18  attack_passes                  20 non-null     int64
#  19  attack_passes_through          20 non-null     int64
#  20  attack_passes_long             20 non-null     int64
#  21  attack_passes_back             20 non-null     int64
#  22  attack_crosses                 20 non-null     int64
#  23  attack_corners_taken           20 non-null     int64
#  24  attack_shots                   20 non-null     int64
#  25  attack_shots_on_target         20 non-null     int64
#  26  attack_goals_headed            20 non-null     int64
#  27  attack_goals_penalty           20 non-null     int64
#  28  attack_goals_box               20 non-null     int64
#  29  attack_goals_outsidebox        20 non-null     int64
#  30  general_card_yellow            20 non-null     int64
#  31  general_card_red               20 non-null     int64
#  32  attack_goals_counter           20 non-null     int64
#  33  attack_goals_freekick          20 non-null     int64
#  34  defence_saves                  20 non-null     int64
#  35  defence_blocks                 20 non-null     int64
#  36  defence_interceptions          20 non-null     int64
#  37  defence_tackles                20 non-null     int64
#  38  defence_tackles_last_man       20 non-null     int64
#  39  defence_clearances             20 non-null     int64
#  40  defence_clearances_headed      20 non-null     int64
#  41  defence_penalty_conceeded      20 non-null     int64
#  42  attack_posession               20 non-null     float64
#  43  attack_pass_accuracy           20 non-null     float64
# dtypes: float64(3), int64(39), object(2)
# memory usage: 7.0+ KB

# %% [markdown]
# ## Collect data which contains a meaning in finance

# %%
dfFinanceData = df[['finance _tv_revenue','finance _team_market','finance _market_average']]
dfFinanceData
# Out:
#     finance _tv_revenue  finance _team_market  finance _market_average
# 0             150986355            1003200000                 39987200
# 1             152425146             836440000                 34848000
# 2             146030216             779460000                 29981600
# 3             145230801             735240000                 29409600
# 4             142193180             701800000                 26989600
# 5             142512868             550440000                 22017600
# 6             127165114             369600000                 16068800
# 7             128603905             305360000                 11748000
# 8             123328078             284240000                 10929600
# 9             122528663             234212000                  9011200
# 10            113895527             229240000                  9169600
# 11            114215215             223520000                  8280800
# 12            120130418             214060000                 10700800
# 13            108139973             200288000                  8008000
# 14            107340558             176440000                  6784800
# 15            104302937             160072000                  5720000
# 16            105741728             152680000                  6635200
# 17            102704107             152020000                  6080800
# 18            101904692             106920000                  4276800
# 19             96628865              85492000                  3053600

# %%
dfFinanceData = dfFinanceData.join(df['Team'])
dfFinanceData
# Out:
#     finance _tv_revenue  finance _team_market  finance _market_average  \
# 0             150986355            1003200000                 39987200
# 1             152425146             836440000                 34848000
# 2             146030216             779460000                 29981600
# 3             145230801             735240000                 29409600
# 4             142193180             701800000                 26989600
# 5             142512868             550440000                 22017600
# 6             127165114             369600000                 16068800
# 7             128603905             305360000                 11748000
# 8             123328078             284240000                 10929600
# 9             122528663             234212000                  9011200
# 10            113895527             229240000                  9169600
# 11            114215215             223520000                  8280800
# 12            120130418             214060000                 10700800
# 13            108139973             200288000                  8008000
# 14            107340558             176440000                  6784800
# 15            104302937             160072000                  5720000
# 16            105741728             152680000                  6635200
# 17            102704107             152020000                  6080800
# 18            101904692             106920000                  4276800
# 19             96628865              85492000                  3053600
#
#                  Team
# 0     Manchester City
# 1           Liverpool
# 2             Chelsea
# 3           Tottenham
# 4             Arsenal
# 5   Manchester United
# 6       Wolverhampton
# 7             Everton
# 8           Leicester
# 9            West Ham
# 10            Watford
# 11     Crystal Palace
# 12          Newcastle
# 13        Bournemouth
# 14            Burnley
# 15        Southampton
# 16           Brighton
# 17            Cardiff
# 18             Fulham
# 19       Huddersfield

# %% [markdown]
# ## Condition Based on Finance TV Revenue

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x=dfFinanceData.index, y="finance _tv_revenue",
    linestyle='--',
    data=dfFinanceData,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='Finance TV Revenue')
# Out:
# [Text(0.5, 1.0, 'Finance TV Revenue')]

# %% [markdown]
# ## Condition Based on Finance Team Market

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x=dfFinanceData.index, y="finance _team_market",
    linestyle='--',
    data=dfFinanceData,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='Finance Team Market')
# Out:
# [Text(0.5, 1.0, 'Finance Team Market')]

# %% [markdown]
# ## Condition Based on Finance Market Average

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x=dfFinanceData.index, y="finance _market_average",
    linestyle='--',
    data=dfFinanceData,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='Finance Market Average')
# Out:
# [Text(0.5, 1.0, 'Finance Market Average')]

# %% [markdown]
# # OBJECTIVE 6
#
# DO CREATIVITY

# %% [markdown]
# ## Scatter Plot MeanAttackData vs MeanDefenceData

# %%
df= df.join(dfDefenceData['MeanDefenceData'])
df= df.join(dfAttackData['MeanAttackData'])
df
# Out:
#                  Team                        category  \
# 0     Manchester City                Champions League
# 1           Liverpool                Champions League
# 2             Chelsea  Champions League Qualification
# 3           Tottenham  Champions League Qualification
# 4             Arsenal                   Europa League
# 5   Manchester United                   Europa League
# 6       Wolverhampton     Europa League Qualification
# 7             Everton            No UEFA Competitions
# 8           Leicester            No UEFA Competitions
# 9            West Ham            No UEFA Competitions
# 10            Watford            No UEFA Competitions
# 11     Crystal Palace            No UEFA Competitions
# 12          Newcastle            No UEFA Competitions
# 13        Bournemouth            No UEFA Competitions
# 14            Burnley            No UEFA Competitions
# 15        Southampton            No UEFA Competitions
# 16           Brighton            No UEFA Competitions
# 17            Cardiff                       Relegated
# 18             Fulham                       Relegated
# 19       Huddersfield                       Relegated
#
#     general_league_position  finance _live_games_televised  \
# 0                         1                             26
# 1                         2                             29
# 2                         3                             25
# 3                         4                             26
# 4                         5                             25
# 5                         6                             27
# 6                         7                             15
# 7                         8                             18
# 8                         9                             15
# 9                        10                             16
# 10                       11                             10
# 11                       12                             12
# 12                       13                             19
# 13                       14                             10
# 14                       15                             11
# 15                       16                             10
# 16                       17                             13
# 17                       18                             12
# 18                       19                             13
# 19                       20                             10
#
#     finance _tv_revenue  general_matches_played  general_won  general_draw  \
# 0             150986355                      38           32             2
# 1             152425146                      38           30             7
# 2             146030216                      38           21             9
# 3             145230801                      38           23             2
# 4             142193180                      38           21             7
# 5             142512868                      38           19             9
# 6             127165114                      38           16             9
# 7             128603905                      38           15             9
# 8             123328078                      38           15             7
# 9             122528663                      38           15             7
# 10            113895527                      38           14             8
# 11            114215215                      38           14             7
# 12            120130418                      38           12             9
# 13            108139973                      38           13             6
# 14            107340558                      38           11             7
# 15            104302937                      38            9            12
# 16            105741728                      38            9             9
# 17            102704107                      38           10             4
# 18            101904692                      38            7             5
# 19             96628865                      38            3             7
#
#     general_lost  attack_scored  ...  defence_interceptions  defence_tackles  \
# 0              4             95  ...                    362              518
# 1              1             89  ...                    314              610
# 2              8             63  ...                    351              618
# 3             13             67  ...                    326              626
# 4             10             73  ...                    412              609
# 5             10             65  ...                    355              581
# 6             13             47  ...                    501              720
# 7             14             54  ...                    456              700
# 8             16             51  ...                    436              676
# 9             16             52  ...                    457              723
# 10            16             52  ...                    426              655
# 11            17             51  ...                    446              730
# 12            17             42  ...                    506              714
# 13            19             56  ...                    371              526
# 14            20             45  ...                    365              583
# 15            17             45  ...                    548              699
# 16            20             35  ...                    463              681
# 17            24             34  ...                    528              655
# 18            26             34  ...                    433              591
# 19            28             22  ...                    530              710
#
#     defence_tackles_last_man  defence_clearances  defence_clearances_headed  \
# 0                          0                 543                        295
# 1                          2                 639                        317
# 2                          2                 593                        330
# 3                          3                 770                        411
# 4                          2                 762                        404
# 5                          2                 785                        370
# 6                          2                 824                        464
# 7                          4                 825                        430
# 8                          4                 945                        500
# 9                          5                 855                        397
# 10                         8                 956                        447
# 11                         2                 940                        467
# 12                         4                1120                        564
# 13                         5                1019                        515
# 14                         5                1080                        539
# 15                         4                1068                        502
# 16                         4                 921                        499
# 17                         4                 978                        448
# 18                         0                 971                        443
# 19                         2                 658                        246
#
#     defence_penalty_conceeded  attack_posession  attack_pass_accuracy  \
# 0                           4              64.0                  89.0
# 1                           1              58.8                  84.4
# 2                           2              59.9                  87.6
# 3                           5              56.7                  83.2
# 4                           7              56.1                  83.3
# 5                           6              53.3                  82.3
# 6                           4              47.4                  78.2
# 7                           5              51.0                  77.3
# 8                           5              50.8                  79.2
# 9                           5              49.0                  78.7
# 10                          5              47.4                  76.1
# 11                          5              46.6                  76.8
# 12                          7              42.9                  72.9
# 13                          5              47.7                  78.1
# 14                          5              43.4                  70.3
# 15                          3              45.4                  74.0
# 16                         10              44.1                  74.8
# 17                          8              39.1                  63.9
# 18                          7              49.2                  80.3
# 19                          8              47.1                  75.8
#
#     MeanDefenceData  MeanAttackData
# 0        262.714286     1995.500000
# 1        290.857143     1791.566667
# 2        293.142857     1864.250000
# 3        338.428571     1630.272222
# 4        348.571429     1577.244444
# 5        334.714286     1480.700000
# 6        394.142857     1335.811111
# 7        370.571429     1331.961111
# 8        392.428571     1386.611111
# 9        389.428571     1295.372222
# 10       391.285714     1243.916667
# 11       405.571429     1222.522222
# 12       448.142857     1145.822222
# 13       385.428571     1248.433333
# 14       419.142857     1122.872222
# 15       441.142857     1175.188889
# 16       407.000000     1162.994444
# 17       414.428571      900.500000
# 18       389.857143     1393.916667
# 19       341.428571     1300.883333
#
# [20 rows x 46 columns]

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='MeanAttackData', y="MeanDefenceData",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='MeanAttackData VS MeanDefenceData')
# Out:
# [Text(0.5, 1.0, 'MeanAttackData VS MeanDefenceData')]

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='MeanAttackData', y="MeanDefenceData",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['category'],
).set(title='MeanAttackData VS MeanDefenceData by Category')
# Out:
# [Text(0.5, 1.0, 'MeanAttackData VS MeanDefenceData by Category')]

# %% [markdown]
# ## Scatter Plot finance_live_games_televised vs finance_tv_revenue

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='finance _live_games_televised', y="finance _tv_revenue",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='finance_live_games_televised vs finance_tv_revenue')
# Out:
# [Text(0.5, 1.0, 'finance_live_games_televised vs finance_tv_revenue')]

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='finance _live_games_televised', y="finance _tv_revenue",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['category'],
).set(title='finance_live_games_televised vs finance_tv_revenue by category')
# Out:
# [Text(0.5, 1.0, 'finance_live_games_televised vs finance_tv_revenue by category')]

# %% [markdown]
# ## Scatter plot between attack_shots, attack_shots_on_target, and attack_scored

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='attack_shots_on_target', y="attack_shots",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='attack_shots_on_target vs attack shots')
# Out:
# [Text(0.5, 1.0, 'attack_shots_on_target vs attack shots')]

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='attack_shots', y="attack_scored",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='attack shots vs attack_scored')
# Out:
# [Text(0.5, 1.0, 'attack shots vs attack_scored')]

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='attack_shots_on_target', y="attack_scored",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='attack_shots_on_target vs attack_scored')
# Out:
# [Text(0.5, 1.0, 'attack_shots_on_target vs attack_scored')]

# %% [markdown]
# ## Yellow Card vs Red Card in Each Team

# %%
fig, ax = plt.subplots(figsize=(15,10))


sns.scatterplot(
    x='general_card_yellow', y="general_card_red",
    linestyle='--',
    data=df,
    s=160,
    ax=ax,
    hue = df['Team'],
).set(title='Yellow Card vs Red Card in Each Team')
# Out:
# [Text(0.5, 1.0, 'Yellow Card vs Red Card in Each Team')]
